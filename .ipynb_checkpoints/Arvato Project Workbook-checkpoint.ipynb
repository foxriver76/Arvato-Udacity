# %% [markdown]
# ## Method definitions

# %%
def clean_df(df, cols_to_drop):
    """
    Drops columns and does performs basic encodings

    INPUT:
    df: DataFrame to clean
    cols_to_drop: list of columns which will be droped
    
    OUTPUT:
    cleaned_df: Cleaned DataFrame
    """
    
    df.drop(columns=cols_to_drop, inplace=True)
    # EINGEFUEGT_AM to datetime
    df.EINGEFUEGT_AM = pd.to_datetime(df.EINGEFUEGT_AM, format='%Y-%m-%d ').dt.year
    
    # OST_WEST_KZ O, W to 0, 1
    df.OST_WEST_KZ.replace('O', 0, inplace=True)
    df.OST_WEST_KZ.replace('W', 1, inplace=True)
    
    # clean cameo
    df.CAMEO_DEUG_2015 = pd.to_numeric(df.CAMEO_DEUG_2015).astype(str)
    
    # drop rows with more than 0.08 % (29) of missing values
    df.dropna(axis=0, inplace=True, thresh=df.shape[1] - 29)
    
    return df

# %%
def encode_to_nan(df, encodings):
    """
    Takes a DataFrame and replaces the keys which are given by encoding the default nan value with real nan
    
    INPUT:
    df: DataFrame to encode
    encodings: DataFrame with encodings
    
    OUTPUT:
    encoded_df: Encoded DataFrame
    """
    
    for idx, row in encodings.iterrows():
        placeholder = row.Value
        encoding = row.Attribute
                
        try:
            col_type = df[encoding].dtype
        except KeyError:
            continue # col not in DF
        
        if col_type == np.int64 or col_type == np.float64:
            try:
                placeholder = int(placeholder)
            except:
                continue
        
        df[encoding].replace(placeholder, np.nan, inplace=True)
        
    return df

# %% [markdown]
# # Capstone Project: Create a Customer Segmentation Report for Arvato Financial Services
#
# In this project, you will analyze demographics data for customers of a mail-order sales company in Germany, comparing it against demographics information for the general population. You'll use unsupervised learning techniques to perform customer segmentation, identifying the parts of the population that best describe the core customer base of the company. Then, you'll apply what you've learned on a third dataset with demographics information for targets of a marketing campaign for the company, and use a model to predict which individuals are most likely to convert into becoming customers for the company. The data that you will use has been provided by our partners at Bertelsmann Arvato Analytics, and represents a real-life data science task.
#
# The versions of those two datasets used in this project will include many more features and has not been pre-cleaned. You are also free to choose whatever approach you'd like to analyzing the data rather than follow pre-determined steps. In your work on this project, make sure that you carefully document your steps and decisions, since your main deliverable for this project will be a blog post reporting your findings.

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans

# magic word for producing visualizations in notebook
# %matplotlib inline

matplotlib.rc('figure', figsize=(16, 8))

# %% [markdown]
# ## Part 0: Get to Know the Data
#
# There are four data files associated with this project:
#
# - `Udacity_AZDIAS_052018.csv`: Demographics data for the general population of Germany; 891 211 persons (rows) x 366 features (columns).
# - `Udacity_CUSTOMERS_052018.csv`: Demographics data for customers of a mail-order company; 191 652 persons (rows) x 369 features (columns).
# - `Udacity_MAILOUT_052018_TRAIN.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 982 persons (rows) x 367 (columns).
# - `Udacity_MAILOUT_052018_TEST.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 833 persons (rows) x 366 (columns).
#
# Each row of the demographics files represents a single person, but also includes information outside of individuals, including information about their household, building, and neighborhood. Use the information from the first two files to figure out how customers ("CUSTOMERS") are similar to or differ from the general population at large ("AZDIAS"), then use your analysis to make predictions on the other two files ("MAILOUT"), predicting which recipients are most likely to become a customer for the mail-order company.
#
# The "CUSTOMERS" file contains three extra columns ('CUSTOMER_GROUP', 'ONLINE_PURCHASE', and 'PRODUCT_GROUP'), which provide broad information about the customers depicted in the file. The original "MAILOUT" file included one additional column, "RESPONSE", which indicated whether or not each recipient became a customer of the company. For the "TRAIN" subset, this column has been retained, but in the "TEST" subset it has been removed; it is against that withheld column that your final predictions will be assessed in the Kaggle competition.
#
# Otherwise, all of the remaining columns are the same between the three data files. For more information about the columns depicted in the files, you can refer to two Excel spreadsheets provided in the workspace. [One of them](./DIAS Information Levels - Attributes 2017.xlsx) is a top-level list of attributes and descriptions, organized by informational category. [The other](./DIAS Attributes - Values 2017.xlsx) is a detailed mapping of data values for each feature in alphabetical order.
#
# In the below cell, we've provided some initial code to load in the first two datasets. Note for all of the `.csv` data files in this project that they're semicolon (`;`) delimited, so an additional argument in the [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) call has been included to read in the data properly. Also, considering the size of the datasets, it may take some time for them to load completely.
#
# You'll notice when the data is loaded in that a warning message will immediately pop up. Before you really start digging into the modeling and analysis, you're going to need to perform some cleaning. Take some time to browse the structure of the data and look over the informational spreadsheets to understand the data values. Make some decisions on which features to keep, which features to drop, and if any revisions need to be made on data formats. It'll be a good idea to create a function with pre-processing steps, since you'll need to clean all of the datasets before you work with them.

# %%
# load in the data
customers = pd.read_csv('./arvato-data/Udacity_CUSTOMERS_052018.csv', sep=';')
# Out:
# /home/moritz/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
azdias = pd.read_csv('./arvato-data/Udacity_AZDIAS_052018.csv', sep=';')

# %%
customers.head()
# Out:
#       LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0    9626         2         1.0      10.0          NaN          NaN
# 1    9628        -1         9.0      11.0          NaN          NaN
# 2  143872        -1         1.0       6.0          NaN          NaN
# 3  143873         1         1.0       8.0          NaN          NaN
# 4  143874        -1         1.0      20.0          NaN          NaN
#
#    ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  ...  \
# 0          NaN          NaN                  10.0                  1.0  ...
# 1          NaN          NaN                   NaN                  NaN  ...
# 2          NaN          NaN                   0.0                  1.0  ...
# 3          NaN          NaN                   8.0                  0.0  ...
# 4          NaN          NaN                  14.0                  7.0  ...
#
#    VK_ZG11  W_KEIT_KIND_HH  WOHNDAUER_2008  WOHNLAGE  ZABEOTYP  \
# ...

# %%
# lets take a look at the general population
azdias.head()
# Out:
#       LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0  910215        -1         NaN       NaN          NaN          NaN
# 1  910220        -1         9.0       0.0          NaN          NaN
# 2  910225        -1         9.0      17.0          NaN          NaN
# 3  910226         2         1.0      13.0          NaN          NaN
# 4  910241        -1         1.0      20.0          NaN          NaN
#
#    ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  ...  \
# 0          NaN          NaN                   NaN                  NaN  ...
# 1          NaN          NaN                  21.0                 11.0  ...
# 2          NaN          NaN                  17.0                 10.0  ...
# 3          NaN          NaN                  13.0                  1.0  ...
# 4          NaN          NaN                  14.0                  3.0  ...
#
#    VHN  VK_DHT4A  VK_DISTANZ  VK_ZG11  W_KEIT_KIND_HH  WOHNDAUER_2008  \
# ...

# %%
azdias.select_dtypes(['object']).head()
# Out:
#   CAMEO_DEU_2015 CAMEO_DEUG_2015 CAMEO_INTL_2015 D19_LETZTER_KAUF_BRANCHE  \
# 0            NaN             NaN             NaN                      NaN
# 1             8A               8              51                      NaN
# 2             4C               4              24            D19_UNBEKANNT
# 3             2A               2              12            D19_UNBEKANNT
# 4             6B               6              43               D19_SCHUHE
#
#          EINGEFUEGT_AM OST_WEST_KZ
# 0                  NaN         NaN
# 1  1992-02-10 00:00:00           W
# 2  1992-02-12 00:00:00           W
# 3  1997-04-21 00:00:00           W
# 4  1992-02-12 00:00:00           W

# %%
customers.select_dtypes(['object']).head()
# Out:
#   CAMEO_DEU_2015 CAMEO_DEUG_2015 CAMEO_INTL_2015 D19_LETZTER_KAUF_BRANCHE  \
# 0             1A               1              13            D19_UNBEKANNT
# 1            NaN             NaN             NaN         D19_BANKEN_GROSS
# 2             5D               5              34            D19_UNBEKANNT
# 3             4C               4              24   D19_NAHRUNGSERGAENZUNG
# 4             7B               7              41               D19_SCHUHE
#
#          EINGEFUEGT_AM OST_WEST_KZ      PRODUCT_GROUP CUSTOMER_GROUP
# 0  1992-02-12 00:00:00           W  COSMETIC_AND_FOOD    MULTI_BUYER
# 1                  NaN         NaN               FOOD   SINGLE_BUYER
# 2  1992-02-10 00:00:00           W  COSMETIC_AND_FOOD    MULTI_BUYER
# 3  1992-02-10 00:00:00           W           COSMETIC    MULTI_BUYER
# 4  1992-02-12 00:00:00           W               FOOD    MULTI_BUYER

# %%
azdias.OST_WEST_KZ.unique()
# Out:
# array([nan, 'W', 'O'], dtype=object)

# %%
customers.PRODUCT_GROUP.unique() # only exists for customers
# Out:
# array(['COSMETIC_AND_FOOD', 'FOOD', 'COSMETIC'], dtype=object)

# %%
customers.CUSTOMER_GROUP.unique() # binary
# Out:
# array(['MULTI_BUYER', 'SINGLE_BUYER'], dtype=object)

# %% [markdown]
# We also can encode binary OST_WEST for both DFs, we will write a clean_df method which does that. See under Metho definitions at top of the Notebook.
#
# Furthermore, the Date column needs to be parsed.

# %% [markdown]
# We are very high dimensional having 369 (366 on the general data) dimensions, it seems that we also have lots of NaN values, we will further check this.

# %% [markdown]
# According to the Excel files we have more values which could be NaN to but are currently encoded as a string, but lets see how they are currently encoded e.g. AGER_TYP -1 means missing

# %%
azdias.AGER_TYP
# Out:
# 0        -1
# 1        -1
# 2        -1
# 3         2
# 4        -1
#          ..
# 891216   -1
# 891217   -1
# 891218   -1
# 891219   -1
# 891220   -1
# Name: AGER_TYP, Length: 891221, dtype: int64

# %% [markdown]
# We should encode -1 etc from Excel to nan, as it indicates a missing value, so we can get real insights about the missing data per column.

# %%
encodings = pd.read_excel('DIAS Attributes - Values 2017.xlsx', usecols='B:E', dtype='str', header=1)

# %%
encodings.head()
# Out:
#   Attribute         Description Value                     Meaning
# 0  AGER_TYP  best-ager typology    -1                     unknown
# 1       NaN                 NaN     0  no classification possible
# 2       NaN                 NaN     1             passive elderly
# 3       NaN                 NaN     2            cultural elderly
# 4       NaN                 NaN     3   experience-driven elderly

# %%
idx_mask = encodings.Meaning.str.contains('unknown').replace(np.nan, False)

nan_encodings = encodings[idx_mask]

# %%
# Lets look at the CAMEO classes
print(azdias.CAMEO_DEUG_2015.unique())
print(azdias.CAMEO_INTL_2015.unique())
print(azdias.CAMEO_DEU_2015.unique())
# Out:
# [nan 8.0 4.0 2.0 6.0 1.0 9.0 5.0 7.0 3.0 '4' '3' '7' '2' '8' '9' '6' '5'
#  '1' 'X']
# [nan 51.0 24.0 12.0 43.0 54.0 22.0 14.0 13.0 15.0 33.0 41.0 34.0 55.0 25.0
#  23.0 31.0 52.0 35.0 45.0 44.0 32.0 '22' '24' '41' '12' '54' '51' '44'
#  '35' '23' '25' '14' '34' '52' '55' '31' '32' '15' '13' '43' '33' '45'
#  'XX']
# [nan '8A' '4C' '2A' '6B' '8C' '4A' '2D' '1A' '1E' '9D' '5C' '8B' '7A' '5D'
#  '9E' '9B' '1B' '3D' '4E' '4B' '3C' '5A' '7B' '9A' '6D' '6E' '2C' '7C'
#  '9C' '7D' '5E' '1D' '8D' '6C' '6A' '5B' '4D' '3A' '2B' '7E' '3B' '6F'
#  '5F' '1C' 'XX']

# %%
print(azdias.GEBURTSJAHR.max())
azdias.GEBURTSJAHR.min()
# Out:
# 2017
# 0

# %% [markdown]
# __DEUG and INTL should be handled as integer (later) and we need to replace X and XX with nan everywhere as it is invalid, zero GEBURTSJAHR is also invalid__

# %%
add_encodings = pd.DataFrame([
    ['CAMEO_DEUG_2015', '', 'X', 'unknown'],
    ['CAMEO_INTL_2015', '', 'XX', 'unknown'],
    ['CAMEO_DEU_2015', '', 'XX', 'unknown'],
    ['GEBURTSJAHR', '', '0', 'unknown']
], columns=nan_encodings.columns)

# %%
add_encodings
# Out:
#          Attribute Description Value  Meaning
# 0  CAMEO_DEUG_2015                 X  unknown
# 1  CAMEO_INTL_2015                XX  unknown
# 2   CAMEO_DEU_2015                XX  unknown
# 3      GEBURTSJAHR                 0  unknown

# %%
nan_encodings = pd.concat((nan_encodings, add_encodings))

# %%
# thats 233 encodings for nan, we should now replace them
encode_to_nan(azdias, nan_encodings)
# Out:
#            LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0       910215       NaN         NaN       NaN          NaN          NaN
# 1       910220       NaN         9.0       NaN          NaN          NaN
# 2       910225       NaN         9.0      17.0          NaN          NaN
# 3       910226       2.0         1.0      13.0          NaN          NaN
# 4       910241       NaN         1.0      20.0          NaN          NaN
# ...        ...       ...         ...       ...          ...          ...
# 891216  825761       NaN         5.0      17.0          NaN          NaN
# 891217  825771       NaN         9.0      16.0          NaN          NaN
# 891218  825772       NaN         1.0      17.0          NaN          NaN
# 891219  825776       NaN         9.0       NaN         17.0          NaN
# 891220  825787       NaN         1.0       NaN          NaN          NaN
#
#         ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  \
# ...

# %%
azdias.GEBURTSJAHR.min() # 1900 maybe okay
# Out:
# 1900.0

# %%
# Lets look again at the CAMEO classes
print(azdias.CAMEO_DEUG_2015.unique())
print(azdias.CAMEO_INTL_2015.unique())
print(azdias.CAMEO_DEU_2015.unique())
# Out:
# [nan 8.0 4.0 2.0 6.0 1.0 9.0 5.0 7.0 3.0 '4' '3' '7' '2' '8' '9' '6' '5'
#  '1']
# [nan 51.0 24.0 12.0 43.0 54.0 22.0 14.0 13.0 15.0 33.0 41.0 34.0 55.0 25.0
#  23.0 31.0 52.0 35.0 45.0 44.0 32.0 '22' '24' '41' '12' '54' '51' '44'
#  '35' '23' '25' '14' '34' '52' '55' '31' '32' '15' '13' '43' '33' '45']
# [nan '8A' '4C' '2A' '6B' '8C' '4A' '2D' '1A' '1E' '9D' '5C' '8B' '7A' '5D'
#  '9E' '9B' '1B' '3D' '4E' '4B' '3C' '5A' '7B' '9A' '6D' '6E' '2C' '7C'
#  '9C' '7D' '5E' '1D' '8D' '6C' '6A' '5B' '4D' '3A' '2B' '7E' '3B' '6F'
#  '5F' '1C']

# %%
fig = (azdias.isna().sum(axis=0) / azdias.shape[0] * 100).sort_values(ascending=False).iloc[0:100].plot(kind='bar', figsize=(16,8), title='Columns with missing values');

fig.set_xlabel('Attribute')
fig.set_ylabel('Missing values %')
fig.figure.savefig('100_missing_values.png', dpi=500);

# %% [markdown]
# We can see, that we have many NaN values columns, we should drop columns with too many missing values.
# We draw the line at 25 %.

# %%
# lets find columns with more than 30 % NaN values
na_srs = ((azdias.isna().sum(axis=0) / azdias.shape[0]) >= 0.25)
na_cols = na_srs[na_srs == True].index.tolist()

# free mem
del na_srs

na_cols
# Out:
# ['AGER_TYP',
#  'ALTER_HH',
#  'ALTER_KIND1',
#  'ALTER_KIND2',
#  'ALTER_KIND3',
#  'ALTER_KIND4',
#  'ALTERSKATEGORIE_FEIN',
#  'D19_BANKEN_ONLINE_QUOTE_12',
#  'D19_GESAMT_ONLINE_QUOTE_12',
#  'D19_KONSUMTYP',
#  'D19_LETZTER_KAUF_BRANCHE',
#  'D19_LOTTO',
#  'D19_SOZIALES',
#  'D19_TELKO_ONLINE_QUOTE_12',
#  'D19_VERSAND_ONLINE_QUOTE_12',
#  'D19_VERSI_ONLINE_QUOTE_12',
#  'EXTSEL992',
#  'GEBURTSJAHR',
#  'KK_KUNDENTYP']

# %%
na_cols.append('LNR') # LNR is just an id

# %%
# Also check rows with many missing values
na_rows = azdias.isna().sum(axis=1)

# %%
num_cols = azdias.shape[1]
most_missing_rows = (na_rows / num_cols * 100).sort_values(ascending=False)
most_missing_rows
# Out:
# 350182    71.584699
# 55664     71.584699
# 826869    71.584699
# 537799    71.584699
# 373501    71.584699
#             ...
# 133361     0.000000
# 197845     0.000000
# 450068     0.000000
# 74526      0.000000
# 561703     0.000000
# Length: 891221, dtype: float64

# %%
plt.plot(most_missing_rows.values);
plt.title('Number of missing values')
plt.ylabel('% Missing per row')
plt.xlabel('No rows')
plt.savefig('missing_val_per_row.png', dpi=500)

# %% [markdown]
# __We can see, that we have rows with many missing values, we should find a good threshold to drop columns with too many nans. Especially around around 8 % it flattens a lot, lets check how many rows we will really loose if we drop rows with more than 8 % missing columns. According to the plot it should be around 150,000 of our 890,000 rows.__

# %%
loosing_cols = most_missing_rows[most_missing_rows > 8].shape[0]
loosing_cols
# Out:
# 141401

# %%
# We will loose 142,380 cols
# 8 % of nans is
total_nan = 0.08 * azdias.shape[1]

print(f'Percentual loosing {round(loosing_cols / azdias.shape[0] * 100, 2)} % rows but this way we are getting rid of any row with more than 8 % ({round(total_nan)} entries) of nans!')
# Out:
# Percentual loosing 15.87 % rows but this way we are getting rid of any row with more than 8 % (29 entries) of nans!

# %%
# We have three different CAMEO classifications, lets reduce to one
print(azdias.CAMEO_DEU_2015.isna().tolist().count(True))
print(azdias.CAMEO_INTL_2015.isna().tolist().count(True))
print(azdias.CAMEO_DEUG_2015.isna().tolist().count(True))
# Out:
# 99352
# 99352
# 99352

# %%
# all have same number of missing values, so lets got for the simpelst model
print(azdias.CAMEO_DEU_2015.unique().size)
print(azdias.CAMEO_INTL_2015.unique().size)
print(azdias.CAMEO_DEUG_2015.unique().size)
# Out:
# 45
# 43
# 19

# %%
na_cols.extend(['CAMEO_DEU_2015', 'CAMEO_INTL_2015'])

# %% [markdown]
# __We put this threshold of 29 entries into our clean_df method__

# %%
clean_df(azdias, na_cols)
# Out:
#         AKT_DAT_KL  ANZ_HAUSHALTE_AKTIV  ANZ_HH_TITEL  ANZ_KINDER  \
# 1              9.0                 11.0           0.0         0.0
# 2              9.0                 10.0           0.0         0.0
# 3              1.0                  1.0           0.0         0.0
# 4              1.0                  3.0           0.0         0.0
# 5              1.0                  5.0           0.0         0.0
# ...            ...                  ...           ...         ...
# 891216         5.0                 15.0           0.0         0.0
# 891217         9.0                 11.0           0.0         0.0
# 891218         1.0                  3.0           0.0         0.0
# 891219         9.0                  7.0           0.0         1.0
# 891220         1.0                 10.0           0.0         0.0
#
#         ANZ_PERSONEN  ANZ_STATISTISCHE_HAUSHALTE  ANZ_TITEL  ARBEIT  BALLRAUM  \
# 1                2.0                        12.0        0.0     3.0       6.0
# ...

# %%
azdias.select_dtypes(['object']).head()
# Out:
#   CAMEO_DEUG_2015
# 1             8.0
# 2             4.0
# 3             2.0
# 4             6.0
# 5             8.0

# %%
azdias.CAMEO_DEUG_2015.unique()
# Out:
# array(['8.0', '4.0', '2.0', '6.0', '1.0', '9.0', '7.0', '5.0', '3.0',
#        'nan'], dtype=object)

# %%
azdias.shape
# Out:
# (751322, 344)

# %% [markdown]
# __Perfect, only one categorical value is left and the DF is cleaned__

# %% [markdown]
# ## Next: Imputation and Scaling
#
# We need to fill missing values now and also preprocess the data so our model can work flawlessly with the data.
#
# - We will fill numerical data with the median of the attribute, the median is not prone to outliers as mean, afterwards, we will standardize the mean = 0, std=1 the data
# - We will OHE categorical data, missing values will be filled with the mode (most frequent value)
# - Binary values can stay as they are, and will be filled with mode

# %%
# lets first find binary attributes (attribures which only have 2 values if we exclude nan)
bin_dims = []

for column in azdias.columns:
    if azdias[column].dropna().unique().size == 2:
        bin_dims.append(column)

# %%
bin_dims
# Out:
# ['DSL_FLAG',
#  'GREEN_AVANTGARDE',
#  'HH_DELTA_FLAG',
#  'KONSUMZELLE',
#  'OST_WEST_KZ',
#  'SOHO_KZ',
#  'UNGLEICHENN_FLAG',
#  'VERS_TYP',
#  'ANREDE_KZ']

# %%
# remember our cat attribute from preprocessing, which we have already encoded to num
cat_dims = ['CAMEO_DEUG_2015']

# %%
non_num_dims = cat_dims + bin_dims
num_dims = list(set(azdias.columns.tolist()).difference(set(non_num_dims)))

num_dims
# Out:
# ['KBA13_KRSSEG_VAN',
#  'FINANZ_HAUSBAUER',
#  'PLZ8_ANTG3',
#  'KBA05_KRSVAN',
#  'KBA13_HALTER_45',
#  'KBA13_BJ_2004',
#  'D19_LEBENSMITTEL',
#  'D19_BANKEN_ONLINE_DATUM',
#  'ARBEIT',
#  'KBA13_ANTG4',
#  'SEMIO_REL',
#  'KBA05_MOTOR',
#  'INNENSTADT',
#  'D19_TELKO_ONLINE_DATUM',
#  'KBA13_ALTERHALTER_60',
#  'KBA13_ANTG3',
#  'KBA13_FAB_ASIEN',
#  'KBA13_NISSAN',
#  'KBA05_AUTOQUOT',
#  'SEMIO_SOZ',
#  'SEMIO_FAM',
#  'PLZ8_GBZ',
#  'D19_KONSUMTYP_MAX',
#  'KBA13_FAB_SONSTIGE',
#  'KBA13_VORB_0',
#  'KBA13_KW_40',
#  'GEBAEUDETYP',
#  'D19_VERSAND_OFFLINE_DATUM',
#  'D19_VERSAND_ONLINE_DATUM',
#  'ONLINE_AFFINITAET',
#  'D19_GESAMT_ANZ_12',
#  'D19_GESAMT_OFFLINE_DATUM',
#  'KBA05_ALTER3',
#  'KBA05_MAXVORB',
#  'SEMIO_KULT',
#  'D19_TELKO_ANZ_12',
#  'KBA13_BJ_2009',
#  'KBA05_KW3',
#  'D19_VERSI_ONLINE_DATUM',
#  'KBA13_KMH_140',
#  'KBA05_CCM4',
#  'KBA05_MOD2',
#  'SEMIO_KAEM',
#  'ANZ_HAUSHALTE_AKTIV',
#  'FIRMENDICHTE',
#  'KBA13_CCM_1401_2500',
#  'KBA05_SEG2',
# ...

# %%
# Now lets create the pipeline for binary values
bin_pipe = Pipeline([('bin_imputation', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))])

# %%
# for all of our numerical values, which are not categorical we need a pipeline to replace nan and impute median
num_pipe = Pipeline([
    ('num_imputation', SimpleImputer(missing_values=np.nan, strategy='median')),
    ('standardize', StandardScaler())
])

# %%
# now the categorical pipeline is left, instead of pandas get dummies we use a 
# real OHE transformer to apply same steps to other dfs later
cat_pipe = Pipeline([
    ('mode_imputation', SimpleImputer(missing_values=np.isnan, strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocesser = ColumnTransformer(transformers = [
    ('cat', cat_pipe, cat_dims),
    ('bin', bin_pipe, bin_dims),
    ('num', num_pipe, num_dims)
])

# %% [markdown]
# __Now lets apply the preprocessing__

# %%
azdias_prepro = preprocesser.fit_transform(azdias)

# %%
azdias.shape
# Out:
# (751322, 344)

# %%
azdias_prepro.shape
# Out:
# (751322, 353)

# %%
ohe_dims_enc = list(preprocesser.transformers_[0][1].named_steps['ohe'].get_feature_names(cat_dims))
prepro_col_names = ohe_dims_enc + bin_dims + num_dims

# %% [markdown]
# ## Part 1: Customer Segmentation Report
#
# The main bulk of your analysis will come in this part of the project. Here, you should use unsupervised learning techniques to describe the relationship between the demographics of the company's existing customers and the general population of Germany. By the end of this part, you should be able to describe parts of the general population that are more likely to be part of the mail-order company's main customer base, and which parts of the general population are less so.

# %%
# The goal here should be the form cluster of customers via clustering, we use k-means here
# The problem with clustering is to find a good number of clusters
# A well working heuristic here is the elbow criteria, where we try different no of clusters and look where the error flattens
ks = np.arange(2, 20)
errs = []

for k in ks:
    model = KMeans(n_clusters=k)
    # lets only do this on a subset, else it takes too long
    model.fit(azdias_prepro[:20_000, :])
    errs.append(model.inertia_)
    
errs
# Out:
# [6342776.885695086,
#  5832965.872365565,
#  5647781.084394242,
#  5538940.814904935,
#  5441460.476940272,
#  5368893.618834359,
#  5309917.690600865,
#  5258740.939008945,
#  5221281.584770962,
#  5181858.033754699,
#  5152414.541617798,
#  5127464.10873962,
#  5105326.841216539,
#  5083687.912394506,
#  5064138.522833294,
#  5046788.361893947,
#  5022868.458358065,
#  5014040.172241023]

# %%
plt.plot(ks, errs, '-x')

plt.title('Error by number of clusters')
plt.xlabel('# Clusters')
plt.ylabel('SSE')

plt.savefig('elbow.png', dpi=500)

# %% [markdown]
# __Note that elbow criteria is a heuristic and clustering is an ill-posed problem. However, at around 10 the curve seems to flatten, thus we choose 10 clusters__

# %%
model = KMeans(n_clusters=10)

labels = model.fit(azdias_prepro).predict(azdias_prepro)

# %%
labels.shape
# Out:
# (751322,)

# %%
azdias = pd.concat((azdias, pd.DataFrame(labels, columns=['Cluster'])), axis=1)

# %%
azdias.head()
# Out:
#    AKT_DAT_KL  ANZ_HAUSHALTE_AKTIV  ANZ_HH_TITEL  ANZ_KINDER  ANZ_PERSONEN  \
# 0         NaN                  NaN           NaN         NaN           NaN
# 1         9.0                 11.0           0.0         0.0           2.0
# 2         9.0                 10.0           0.0         0.0           1.0
# 3         1.0                  1.0           0.0         0.0           0.0
# 4         1.0                  3.0           0.0         0.0           4.0
#
#    ANZ_STATISTISCHE_HAUSHALTE  ANZ_TITEL  ARBEIT  BALLRAUM CAMEO_DEUG_2015  \
# 0                         NaN        NaN     NaN       NaN             NaN
# 1                        12.0        0.0     3.0       6.0             8.0
# 2                         7.0        0.0     3.0       2.0             4.0
# 3                         2.0        0.0     2.0       4.0             2.0
# 4                         3.0        0.0     4.0       2.0             6.0
#
# ...

# %% [markdown]
# ### Now also cluster customer data

# %%
encode_to_nan(customers, nan_encodings)
# Out:
#            LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0         9626       2.0         1.0      10.0          NaN          NaN
# 1         9628       NaN         9.0      11.0          NaN          NaN
# 2       143872       NaN         1.0       6.0          NaN          NaN
# 3       143873       1.0         1.0       8.0          NaN          NaN
# 4       143874       NaN         1.0      20.0          NaN          NaN
# ...        ...       ...         ...       ...          ...          ...
# 191647  154561       1.0         1.0       9.0          NaN          NaN
# 191648  154563       NaN         2.0       NaN          NaN          NaN
# 191649  148813       2.0         1.0      15.0          NaN          NaN
# 191650  148852       3.0         1.0      13.0          NaN          NaN
# 191651  148883       3.0         1.0       NaN          NaN          NaN
#
#         ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  \
# ...

# %%
clean_df(customers, na_cols)
# Out:
#         AKT_DAT_KL  ANZ_HAUSHALTE_AKTIV  ANZ_HH_TITEL  ANZ_KINDER  \
# 0              1.0                  1.0           0.0         0.0
# 2              1.0                  1.0           0.0         0.0
# 3              1.0                  0.0           NaN         0.0
# 4              1.0                  7.0           0.0         0.0
# 5              1.0                  1.0           0.0         0.0
# ...            ...                  ...           ...         ...
# 191647         1.0                  1.0           0.0         0.0
# 191648         2.0                  0.0           NaN         0.0
# 191649         1.0                  1.0           0.0         0.0
# 191650         1.0                  4.0           0.0         0.0
# 191651         1.0                  1.0           0.0         0.0
#
#         ANZ_PERSONEN  ANZ_STATISTISCHE_HAUSHALTE  ANZ_TITEL  ARBEIT  BALLRAUM  \
# 0                2.0                         1.0        0.0     1.0       3.0
# ...

# %%
# drop extra columns 'CUSTOMER_GROUP', 'ONLINE_PURCHASE', and 'PRODUCT_GROUP'
customers.drop(columns=['CUSTOMER_GROUP', 'ONLINE_PURCHASE', 'PRODUCT_GROUP'], inplace=True)

# %%
customers.select_dtypes(['object']).head()
# Out:
#   CAMEO_DEUG_2015
# 0             1.0
# 2             5.0
# 3             4.0
# 4             7.0
# 5             5.0

# %%
customers_prepro = preprocesser.fit_transform(customers)

# %%
labels_customers = model.predict(customers_prepro)

# %%
customers = pd.concat((customers, pd.DataFrame(labels_customers, columns=['Cluster'])), axis=1)

# %%
customers.head()
# Out:
#    AKT_DAT_KL  ANZ_HAUSHALTE_AKTIV  ANZ_HH_TITEL  ANZ_KINDER  ANZ_PERSONEN  \
# 0         1.0                  1.0           0.0         0.0           2.0
# 1         NaN                  NaN           NaN         NaN           NaN
# 2         1.0                  1.0           0.0         0.0           1.0
# 3         1.0                  0.0           NaN         0.0           0.0
# 4         1.0                  7.0           0.0         0.0           4.0
#
#    ANZ_STATISTISCHE_HAUSHALTE  ANZ_TITEL  ARBEIT  BALLRAUM CAMEO_DEUG_2015  \
# 0                         1.0        0.0     1.0       3.0             1.0
# 1                         NaN        NaN     NaN       NaN             NaN
# 2                         1.0        0.0     3.0       7.0             5.0
# 3                         1.0        0.0     1.0       7.0             4.0
# 4                         7.0        0.0     3.0       3.0             7.0
#
# ...

# %% [markdown]
# ### Lets visualize and compare

# %%
plt.hist([labels, labels_customers], label=['Population', 'Customer'])

plt.title('Abosulte members per cluster')
plt.xlabel('Cluster')
plt.ylabel('# Members')
plt.legend()
plt.xticks(range(0, 10))
plt.savefig('total_cluster_ratio.png', dpi=500)

# %%
np.unique(labels_customers, return_counts=True)[1] / len(labels_customers) * 100
# Out:
# array([20.73954032,  9.99940801, 15.92298243,  7.63145821,  0.66376593,
#         7.73431603,  5.71267889, 14.27281742,  3.39800796, 13.92502479])

# %% [markdown]
# __We can see, that the the we have cluster with many members and less members, at a first glance it seems to have about an equal raito per cluster no matter if customer or not__

# %%
plt.hist([np.arange(0, 10), np.arange(0, 10)], weights=[
    np.unique(labels, return_counts=True)[1] / len(labels) * 100, 
    np.unique(labels_customers, return_counts=True)[1] / len(labels_customers) * 100
], label=['Population', 'Customer'])

plt.title('Members per Cluster in %')
plt.xlabel('Cluster')
plt.ylabel('% Members')
plt.legend()
plt.xticks(range(0, 10))
plt.savefig('relative_cluster_ratio.png', dpi=500)

# %%
# Okay, we have slight differences, we plot them too

weights = (np.unique(labels, return_counts=True)[1] / len(labels) * 100) - (np.unique(labels_customers, return_counts=True)[1] / len(labels_customers) * 100)

diffs = np.arange(0, 10), 

colors = ['green' if weight > 0 else 'red' for weight in weights]

fig, ax = plt.subplots()

N, bins, patches = ax.hist(diffs, width=.5, weights=weights.reshape(-1, 1))

for i in range(0, 10):
    patches[i].set_facecolor(colors[i])

plt.title('Difference between Cluster of population and customers')
plt.xlabel('Cluster')
plt.ylabel('% Members')
plt.xticks(range(0, 10))
plt.savefig('diffs_cluster_ratio.png', dpi=500)

# %% [markdown]
# __Green means, we have more values (ratio) in our customer group than in the population. Thus the green clusters are those people who are interested in our products. Red clusters are people who are not interested in our products. Thus, we can now look on the cluster means.__

# %%
pos_clust_idx = [1]
neg_clust_idx = [0]

# %%
model.cluster_centers_
# Out:
# array([[ 0.0659434 ,  0.2000052 ,  0.17163481, ..., -0.16730022,
#          0.78112257,  0.05689898],
#        [ 0.03235407,  0.09938599,  0.11683216, ..., -0.05316927,
#         -0.66295182, -0.04499239],
#        [ 0.01115702,  0.01234349,  0.03504262, ...,  0.35064812,
#          0.53955388, -0.23887767],
#        ...,
#        [ 0.07868304,  0.23476279,  0.17442872, ..., -0.22028602,
#          0.08867943,  0.09384416],
#        [ 0.00706686,  0.0036896 ,  0.01602733, ..., -0.06621651,
#          0.0541636 , -0.28856067],
#        [ 0.15426735,  0.13110417,  0.10552625, ..., -0.71568725,
#          0.14956627, -0.10909413]])

# %%
clusters_df = pd.DataFrame(model.cluster_centers_.T, columns=[f'Cluster_{i}' for i in range(0, 10)], index=prepro_col_names)
clusters_df
# Out:
#                      Cluster_0  Cluster_1  Cluster_2  Cluster_3  Cluster_4  \
# CAMEO_DEUG_2015_1.0   0.065943   0.032354   0.011157   0.018927   0.011323
# CAMEO_DEUG_2015_2.0   0.200005   0.099386   0.012343   0.027875   0.021721
# CAMEO_DEUG_2015_3.0   0.171635   0.116832   0.035043   0.053984   0.039952
# CAMEO_DEUG_2015_4.0   0.243072   0.183900   0.037239   0.067088   0.029127
# CAMEO_DEUG_2015_5.0   0.074479   0.070884   0.039570   0.058532   0.046859
# ...                        ...        ...        ...        ...        ...
# KBA13_HERST_SONST    -0.397833  -0.319505  -0.225848  -0.089172   0.299673
# MOBI_RASTER           0.731800   0.062681  -0.646340  -0.523199  -0.635314
# KBA13_BJ_2000        -0.167300  -0.053169   0.350648   0.233437   0.132346
# CJT_TYP_3             0.781123  -0.662952   0.539554  -0.664197   0.159576
# KBA05_SEG9            0.056899  -0.044992  -0.238878  -0.143369   5.455886
#
# ...

# %%
# we compare the most over and underrepresented cluster
important_clust_df = pd.DataFrame(
    clusters_df[['Cluster_0', 'Cluster_1']].values, 
    columns=['0-', '1+'], index=prepro_col_names)

important_clust_df
# Out:
#                            0-        1+
# CAMEO_DEUG_2015_1.0  0.065943  0.032354
# CAMEO_DEUG_2015_2.0  0.200005  0.099386
# CAMEO_DEUG_2015_3.0  0.171635  0.116832
# CAMEO_DEUG_2015_4.0  0.243072  0.183900
# CAMEO_DEUG_2015_5.0  0.074479  0.070884
# ...                       ...       ...
# KBA13_HERST_SONST   -0.397833 -0.319505
# MOBI_RASTER          0.731800  0.062681
# KBA13_BJ_2000       -0.167300 -0.053169
# CJT_TYP_3            0.781123 -0.662952
# KBA05_SEG9           0.056899 -0.044992
#
# [353 rows x 2 columns]

# %%
important_dims = important_clust_df.std(axis=1).sort_values(ascending=False).index.tolist()[0:10]
important_dims
# Out:
# ['CJT_TYP_2',
#  'CJT_TYP_1',
#  'FINANZ_SPARER',
#  'FINANZ_MINIMALIST',
#  'CJT_TYP_5',
#  'FINANZ_VORSORGER',
#  'FINANZ_UNAUFFAELLIGER',
#  'CJT_TYP_3',
#  'ALTERSKATEGORIE_GROB',
#  'FINANZ_ANLEGER']

# %%
# it seems like that our clusters differ by the cars they own, to be sure we need to transform the cluster centers back to the input space
""" preprocesser = ColumnTransformer(transformers = [
    ('cat', cat_pipe, cat_dims),
    ('bin', bin_pipe, bin_dims),
    ('num', num_pipe, num_dims)
])"""
transformer = preprocesser.named_transformers_['num'].named_steps['standardize']
important_clust_df = important_clust_df.T
important_clust_df[num_dims] = transformer.inverse_transform(important_clust_df[num_dims])

# %%
important_clust_df.index
# Out:
# Index(['CAMEO_DEUG_2015_1.0', 'CAMEO_DEUG_2015_2.0', 'CAMEO_DEUG_2015_3.0',
#        'CAMEO_DEUG_2015_4.0', 'CAMEO_DEUG_2015_5.0', 'CAMEO_DEUG_2015_6.0',
#        'CAMEO_DEUG_2015_7.0', 'CAMEO_DEUG_2015_8.0', 'CAMEO_DEUG_2015_9.0',
#        'CAMEO_DEUG_2015_nan',
#        ...
#        'KBA05_DIESEL', 'PLZ8_ANTG2', 'D19_GARTEN', 'KBA05_KRSHERST1',
#        'D19_TELKO_ANZ_24', 'KBA13_HERST_SONST', 'MOBI_RASTER', 'KBA13_BJ_2000',
#        'CJT_TYP_3', 'KBA05_SEG9'],
#       dtype='object', length=353)

# %%
important_clust_df[important_dims].T
# Out:
#                              0-        1+
# CJT_TYP_2              0.928858  2.615066
# CJT_TYP_1              1.126600  2.885022
# FINANZ_SPARER          0.731799  2.134479
# FINANZ_MINIMALIST      5.247645  3.588486
# CJT_TYP_5              5.185959  3.631980
# FINANZ_VORSORGER       5.247035  3.944812
# FINANZ_UNAUFFAELLIGER  1.294033  2.657822
# CJT_TYP_3              5.141105  3.810176
# ALTERSKATEGORIE_GROB   4.008695  2.926753
# FINANZ_ANLEGER         0.977961  2.390822

# %% [markdown]
# __Our customers seem to be segmented by the cars by the cluster algorithm. Our customers tend to like the Customer Joruney type 1, 2, while non buyers prefer type 5 more than customers. Our customers also like to save money traditionally or as an investor while non-customers seem to be more of the ones who like to be prepared or are minimalists. Also our customers are younger than non-customers.__
#
# __Thus, we should address people which have chosen CJT Type 1 or 2 and are of younger age and like to invest money.__

# %%
# Finally lets visualize the clusters via PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=20)

X_trans = pca.fit_transform(azdias_prepro)

# %%
X_trans.shape
# Out:
# (751322, 20)

# %%
import seaborn as sns

df = pd.DataFrame()
df["y"] = labels
df["PC-1"] = X_trans[:,0]
df["PC-2"] = X_trans[:,1]

sns.scatterplot(x="PC-1", y="PC-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 10),
                data=df).set(title="PCA projection");

plt.savefig('PCA.png', dpi=500);

# %% [markdown]
# # Part 2: Supervised Learning Model
#
# Now that you've found which parts of the population are more likely to be customers of the mail-order company, it's time to build a prediction model. Each of the rows in the "MAILOUT" data files represents an individual that was targeted for a mailout campaign. Ideally, we should be able to use the demographic information from each individual to decide whether or not it will be worth it to include that person in the campaign.
#
# The "MAILOUT" data has been split into two approximately equal parts, each with almost 43 000 data rows. In this part, you can verify your model with the "TRAIN" partition, which includes a column, "RESPONSE", that states whether or not a person became a customer of the company following the campaign. In the next part, you'll need to create predictions on the "TEST" partition, where the "RESPONSE" column has been withheld.

# %%
mailout_train = pd.read_csv('./arvato-data/Udacity_MAILOUT_052018_TRAIN.csv', sep=';')
mailout_test = pd.read_csv('./arvato-data/Udacity_MAILOUT_052018_TEST.csv', sep=';')
# Out:
# /home/moritz/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# lets use rslvq as it is a nice prototype based classifier
#!pip install sklearn-lvq
from sklearn_lvq import RslvqModel

# %%
encode_to_nan(mailout_train, nan_encodings)
encode_to_nan(mailout_test, nan_encodings)

clean_df(mailout_train, cols_to_drop=na_cols)
clean_df(mailout_test, cols_to_drop=na_cols)
# Out:
#        AKT_DAT_KL  ANZ_HAUSHALTE_AKTIV  ANZ_HH_TITEL  ANZ_KINDER  \
# 0             1.0                  2.0           0.0         0.0
# 1             1.0                 20.0           0.0         0.0
# 2             9.0                  2.0           0.0         0.0
# 3             7.0                  1.0           0.0         0.0
# 4             1.0                  1.0           0.0         0.0
# ...           ...                  ...           ...         ...
# 42827         1.0                  4.0           0.0         0.0
# 42829         1.0                  2.0           0.0         0.0
# 42830         1.0                  1.0           0.0         2.0
# 42831         1.0                  1.0           0.0         0.0
# 42832         1.0                  1.0           1.0         0.0
#
#        ANZ_PERSONEN  ANZ_STATISTISCHE_HAUSHALTE  ANZ_TITEL  ARBEIT  BALLRAUM  \
# 0               2.0                         2.0        0.0     3.0       6.0
# ...

# %%
# clean both dfs
y = mailout_train.RESPONSE
mailout_train.drop(columns=['RESPONSE'], inplace=True)

# %%
y.shape
# Out:
# (34214,)

# %%
mailout_train_prepro = preprocesser.fit_transform(mailout_train)
mailout_test_prepro = preprocesser.transform(mailout_test)

# %%
mailout_train_prepro.shape
# Out:
# (34214, 353)

# %%
mailout_test_prepro.shape
# Out:
# (34176, 353)

# %%
# train test split the train df
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(mailout_train_prepro, y, test_size=0.3)

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1]), array([10126,   139]))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([23664,   285]))

# %%
# both train and test data are highly imbalanced

# %%
model = RslvqModel(prototypes_per_class=2, sigma=0.5)

# %%
y_pred = model.fit(X_train, y_train).predict(X_test)

# %%
from sklearn.metrics import accuracy_score, cohen_kappa_score, make_scorer

# %%
print(cohen_kappa_score(y_pred, y_test))
accuracy_score(y_pred, y_test)
# Out:
# 0.004276823971204768
# 0.9762299074525085

# %% [markdown]
# __on a first glance at accuracy it seems like RSLVQ is a good choice, however the dataset is highly imbalanced and thus we are reportiung kappa statistics too we can see, that the performance is really bad, thus we probably need a more complex classifier. However, we try oversampling first via SMOTE and RSLVQ__

# %%
#!pip install imblearn
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
x_train_s, y_train_s = sm.fit_resample(X_train, y_train)

# %%
np.unique(y_train_s, return_counts=True)
# Out:
# (array([0, 1]), array([23664, 23664]))

# %%
y_pred_s = model.fit(X_train, y_train).predict(X_test)

print(cohen_kappa_score(y_pred_s, y_test))
accuracy_score(y_pred_s, y_test)
# Out:
# -0.008232747877032098
# 0.9806137359961032

# %%
# kappa score again very worse lets use another classifier
from imblearn.ensemble import RUSBoostClassifier

clf = RUSBoostClassifier()

pred_rus = clf.fit(X_train, y_train).predict(X_test)

print(cohen_kappa_score(pred_rus, y_test))
accuracy_score(pred_rus, y_test)
# Out:
# 0.013031345826427732
# 0.6850462737457379

# %%
# also does not look promising, we try XGBoost
#!pip install xgboost

import xgboost as xgb

clf = xgb.XGBClassifier()

pred_xgb = clf.fit(X_train, y_train).predict(X_test)

print(cohen_kappa_score(pred_xgb, y_test))
accuracy_score(pred_xgb, y_test)
# Out:
# 0.0
# 0.9864588407208963

# %%
# xgboost only predicting majority class, lets combine with SMOTE
pred_xgb = clf.fit(x_train_s, y_train_s).predict(X_test)

print(cohen_kappa_score(pred_xgb, y_test))
accuracy_score(pred_xgb, y_test)
# Out:
# 0.0
# 0.9864588407208963

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier()

y_pred_gbc = gbc.fit(X_train, y_train).predict(X_test)

print(cohen_kappa_score(y_pred_gbc, y_test))
accuracy_score(y_pred_gbc, y_test)
# Out:
# -0.0026448650294297327
# 0.984997564539698

# %%
# and with smote
y_pred_gbc_s = gbc.fit(x_train_s, y_train_s).predict(X_test)

print(cohen_kappa_score(y_pred_gbc_s, y_test))
accuracy_score(y_pred_gbc_s, y_test)
# Out:
# 0.0
# 0.9864588407208963

# %%
from imblearn.ensemble import BalancedRandomForestClassifier

brf = BalancedRandomForestClassifier()

y_pred_brf = gbc.fit(X_train, y_train).predict(X_test)

print(cohen_kappa_score(y_pred_brf, y_test))
accuracy_score(y_pred_brf, y_test)
# Out:
# 0.011886191104740651
# 0.9857769118363371

# %%
brf.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'replacement', 'sampling_strategy', 'verbose', 'warm_start'])

# %%
# gridsearch - okay most promising according to Kappa is RUS or Balanced RF, we take BRF
params = {
    'n_estimators': [50, 100, 300],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 100],
    'min_samples_split': [2, 0.2],
    'n_jobs': [-1],
    'random_state': [42],
    'oob_score': [False, True]
}

# %%
from sklearn.model_selection import GridSearchCV

gs = GridSearchCV(estimator=BalancedRandomForestClassifier(), 
                  param_grid=params, scoring=make_scorer(cohen_kappa_score))

gs.fit(X_train, y_train)
# Out:
# /home/moritz/anaconda3/lib/python3.8/site-packages/imblearn/ensemble/_forest.py:606: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn(
# /home/moritz/anaconda3/lib/python3.8/site-packages/imblearn/ensemble/_forest.py:606: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn(
# /home/moritz/anaconda3/lib/python3.8/site-packages/imblearn/ensemble/_forest.py:606: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn(
# /home/moritz/anaconda3/lib/python3.8/site-packages/imblearn/ensemble/_forest.py:606: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn(
# ...

# %%
clf = gs.best_estimator_

# %%
gs.best_score_
# Out:
# 0.016657653167318022

# %%
gs.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'min_samples_split': 0.2,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': 42}

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns

sns.heatmap(conf_mat / np.sum(conf_mat), annot=True);

# %% [markdown]
# ## Conclusion
# While the unsupervised part of the projcet cannot be evaluated because of its unsupervised nature, it has brought up understandable clusters. The supervised part basically provides very good results w.r.t. accuracy, however we should look at the unbalanced nature of the dataset. The dataset is huge but only a small amount have become customers, thus a good accuracy is achieved by predicting 0 all the time. Hence, we have focused on algorithms which are optimized on unbalanced data. Unfortunately, even after a gridsearch w.r.t. Kappa score with the most promising algorithm the performance stays on a bad level.
